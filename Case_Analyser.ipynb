# %%
# %pip install pdfplumber pytesseract pdf2image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: C:\Users\Lenovo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pdfplumber
import pytesseract
from pdf2image import convert_from_path

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        # Try direct text extraction
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text

        if text.strip():
            return text.strip()
    except Exception as e:
        print(f"Direct text extraction failed: {e}")

    # Fallback to OCR for image-based PDFs
    print("Falling back to OCR for image-based PDF.")
    try:
        images = convert_from_path(pdf_path)
        for image in images:
            page_text = pytesseract.image_to_string(image)
            text += page_text + "\n"
    except Exception as e:
        print(f"OCR failed: {e}")

    return text.strip()

# %%
pdf_path = "CASE STUDY.pdf"  # Replace with the path to your PDF file
case_text = extract_text_from_pdf(pdf_path)

print("\nExtracted Text from PDF:")
print(case_text)
# Out:
# Extracted Text from PDF:
# BuildingBusiness
# Leaders
# SEASON 3
# Case Study
# Tiama Moisturizing Bars
# with Japanese Bokkaido Milk
# Building a New Segment, and
# the Next Frontier: Scaling into General TradeSEASON 3
# A Note to Participants
# This case has been prepared for ITC Limited's campus case study competition. It traces the journey of
# Tiama, one of ITC's flagship personal care brands, through the creation and launch of a new category-de-
# fining innovation — Tiama Moisturizing Bars with Japanese Bokkaido Milk — and the business decisions
# that followed.
# The case is organised in three parts. Part One recounts the Tiama brand story and the market context that
# made a new moisturizing platform an attractive opportunity. Part Two walks through how the range was
# conceived, built and launched across Modern Trade and E-commerce, along with the results that followed.
# ...

# %%
# !pip install -q -U google-genai
# Out:
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: C:\Users\Lenovo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os

os.environ["GEMINI_API_KEY"] = "AQ.AbXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXUPA"

# %%
from google import genai

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

# %%
prompt = f"""
You are an expert case competition consultant, strategy consultant,
and management presentation advisor.

I will provide you with the extracted text of a business case study.

Your job is to analyze the case exactly as a strong MBA/PGDM case
competition participant would.

================ CASE STUDY ================

{case_text}

=============================================

IMPORTANT RULES:

1. First understand the case completely.
2. Use the numbers and facts provided in the case.
3. Do not invent facts, market data, financial numbers, competitors,
   customer segments, or assumptions.
4. Clearly distinguish between:
   - Facts directly given in the case
   - Calculations derived from case data
   - Strategic recommendations/inferences
5. Do not give generic consulting advice.
6. Every recommendation should be connected to evidence from the case.
7. Keep explanations simple and easy to understand.
8. Think like a case competition judge.
9. Prioritize recommendations that are realistic under the case
   constraints.
10. Identify the strongest insight in the entire case.

================================================
SECTION 1 — CASE IN SIMPLE WORDS
================================================

Explain the case as if you are explaining it to a student who has
never seen the case before.

Include:

A. Who is the company?
B. What is happening?
C. What is the main problem?
D. Why is the problem important?
E. What does management/CEO/board want?
F. What constraints must we follow?

Keep this section very simple.

================================================
SECTION 2 — WHAT ARE THEY ACTUALLY ASKING?
================================================

Identify every question the case expects us to answer.

Convert complicated case questions into simple questions.

For example:

Case wording:
"Which customer segments, geographies and channels should
the company prioritize?"

Simple meaning:
"Who should we target, where should we target them,
and how should we reach them?"

================================================
SECTION 3 — IMPORTANT DATA
================================================

Extract the most important numbers from the case.

Create a table with:

Metric | Value | Why it matters

Only include numbers that can influence the strategy.

================================================
SECTION 4 — CASE DIAGNOSIS
================================================

Identify:

1. Core problem
2. Root causes
3. Growth opportunities
4. Threats
5. Customer opportunities
6. Competitive issues
7. Financial issues
8. Operational constraints

Then identify the SINGLE most important strategic insight.

================================================
SECTION 5 — BUSINESS / PORTFOLIO ANALYSIS
================================================

For every major business/product/category in the case:

- Current performance
- Growth potential
- Profitability
- Market attractiveness
- Strategic recommendation

Classify each as:

ACCELERATE
TRANSFORM
MAINTAIN
DEPRIORITIZE
NEW BET

Explain why.

================================================
SECTION 6 — POSSIBLE STRATEGIES
================================================

Develop 3 realistic strategic options.

For each option provide:

Strategy name
Core idea
Why it could work
Advantages
Disadvantages
Investment requirement if supported by case
Risk
Expected impact

Then compare the three options.

================================================
SECTION 7 — RECOMMENDED STRATEGY
================================================

Choose ONE strategy.

Explain:

WHY this strategy?

WHY NOT the alternatives?

What evidence from the case supports it?

How does it satisfy the case constraints?

What should the company do first?

================================================
SECTION 8 — TARGET CUSTOMER
================================================

Identify:

- Primary target segment
- Secondary target segment
- Customer need
- Product/service to offer
- Reason for targeting them

================================================
SECTION 9 — GEOGRAPHY & CHANNEL
================================================

Identify:

- Priority geography
- Why?
- Priority sales/distribution channel
- Why?

Use case data wherever possible.

================================================
SECTION 10 — AI / TECHNOLOGY OPPORTUNITIES
================================================

Identify realistic AI/data/technology opportunities.

For each:

AI initiative
Problem solved
Data required
How it works
Business benefit
Relevant KPI

Do not add unnecessary AI just to make the presentation sound
technological.

================================================
SECTION 11 — 12-MONTH EXECUTION ROADMAP
================================================

Create:

MONTH 1–3
What should happen?

MONTH 4–8
What should happen?

MONTH 9–12
What should happen?

Identify quick wins and long-term initiatives.

================================================
SECTION 12 — KPIs
================================================

Give 5–8 KPIs that management should track.

Include financial, customer, operational and strategic KPIs.

================================================
SECTION 13 — BUSINESS IMPACT
================================================

Calculate business impact wherever the case data allows.

Clearly label:

CASE FACT
DERIVED CALCULATION
ASSUMPTION
RECOMMENDATION

Do not manufacture precise financial results when the case
does not provide enough information.

================================================
SECTION 14 — PPT STRUCTURE
================================================

Now design a 2–3 slide executive case competition presentation.

The presentation should be highly visual and consulting-style,
similar to a winning case competition deck.

SLIDE 1:

Title:
Create a strong strategic headline, NOT a generic title.

Include:

- Strategic thesis
- Portfolio choices
- Growth priorities
- Target segment
- One key strategic chart
- 2–4 important numbers

SLIDE 2:

Title:
Create a strong action-oriented headline.

Include:

- 12-month execution roadmap
- AI / innovation levers
- Key KPIs
- Expected business impact
- One financial/impact visualization

SLIDE 3:

Only create this if necessary.

Possible content:

- Risks and mitigation
- Competitive advantage
- Why we win
- Additional financial bridge

================================================
SECTION 15 — VISUAL & GRAPH STRATEGY
================================================

The PPT MUST be highly visual.

Do NOT create slides that are mostly text.

For every major strategic point, ask:

"Can this information be communicated visually?"

If yes, convert it into a chart, diagram, matrix, flow,
funnel, ladder, roadmap, icon-based visual, or KPI card.

For every slide:

- At least 1 major visual
- At least 2 supporting visual elements
- 2–5 important numerical callouts
- Minimal paragraphs
- Short labels
- Strong visual hierarchy

Use visuals such as:

- Bar charts
- Line charts
- Waterfall charts
- Revenue bridges
- 2x2 matrices
- Portfolio matrices
- Funnels
- Product ladders
- Customer journey diagrams
- Strategy frameworks
- Process flows
- Geographic maps
- KPI cards
- Timelines
- AI/data flow diagrams
- Competitive positioning maps
- Before → After diagrams

Do NOT add visuals simply for decoration.

Every visual must communicate a business insight.

For every recommended graph provide:

Graph type
Title
X-axis
Y-axis
Exact data to use
Source/exhibit
Key message

For every non-chart visual provide:

Visual type
Content
Purpose
Data/information represented

IMPORTANT:

Do not use generic stock images unless they genuinely help explain
the business.

Prefer data-driven visuals, diagrams, icons, product representations,
maps, strategic frameworks and business illustrations.

The final presentation should feel visually rich without becoming
cluttered..


================================================
BRAND RESEARCH & VISUAL IDENTITY
================================================

Before creating the PPT design or Claude prompt, first identify
the company/brand in the case.

IMPORTANT:

You MUST study the company's actual brand identity before deciding
the PPT colors or visual style.

Determine:

1. Company/brand name
2. Whether the company is real or fictional
3. Official website, if it is a real company
4. Official brand colors
5. Primary brand color
6. Secondary brand color
7. Accent colors
8. Typical background colors
9. Typography style, if known
10. Logo style
11. Overall visual personality of the brand

PRIORITY FOR BRAND RESEARCH:

1. Official brand guidelines
2. Official company website
3. Official investor presentations/reports
4. Official company presentations
5. Other reliable sources only if official information is unavailable

IMPORTANT:

DO NOT randomly choose colors based on the industry.

For example:

Do NOT assume:
Technology = blue/purple
Finance = blue
Healthcare = green
Luxury = black/gold

The actual company brand identity must determine the colors.

If the company is fictional OR its official brand identity cannot
be verified, clearly state this.

In that situation, create a restrained professional palette based
ONLY on the visual cues available in the case and clearly label it:

"PROPOSED CASE DESIGN PALETTE"

Do NOT pretend that a proposed palette is an official brand palette.

================================================
STRICT COLOR RULE
================================================

The final PPT MUST primarily use the company's actual brand colors.

Use:

- Official primary brand color
- Official secondary brand color
- Official accent colors where appropriate
- White/off-white
- Black/dark grey
- Controlled tints and shades of the official colors

DO NOT introduce unrelated colors.

DO NOT use:

- Random purple
- Random pink
- Random orange
- Neon colors
- Rainbow colors
- Unrelated gradients
- Multiple unrelated accent colors

The presentation should look as though it was designed by the
company's own strategy team.

Provide:

PRIMARY COLOR:
HEX: ______

SECONDARY COLOR:
HEX: ______

ACCENT COLOR:
HEX: ______

DARK COLOR:
HEX: ______

LIGHT COLOR:
HEX: ______

BACKGROUND:
HEX: ______

Also explain exactly where each color should be used.

================================================
SECTION 17 — CLAUDE PPT PROMPT
================================================

================================================
CLAUDE PPT PROMPT
================================================

Finally create a READY-TO-COPY PROMPT for Claude.

The Claude prompt must instruct Claude to create a professional,
highly visual 2–3 slide executive case competition presentation.

The PPT should look like a strategy consulting / investment banking /
MBA case competition presentation.

================================================
CRITICAL BRAND INSTRUCTION
================================================

Before designing the presentation, use the following brand research:

COMPANY:
[Company name]

BRAND TYPE:
[Real company / Fictional case company]

OFFICIAL WEBSITE:
[Website if verified]

PRIMARY BRAND COLOR:
[Color + HEX]

SECONDARY BRAND COLOR:
[Color + HEX]

ACCENT COLOR:
[Color + HEX]

BACKGROUND:
[Color + HEX]

TEXT COLOR:
[Color + HEX]

VISUAL STYLE:
[Description]

IMPORTANT:

Use the company's REAL brand colors.

Do NOT invent a new color palette.

Do NOT introduce unrelated colors.

Use only:

- Official brand colors
- White/off-white
- Black/dark grey
- Tints and shades of official brand colors

Do NOT use random:

- Purple
- Pink
- Orange
- Neon colors
- Rainbow gradients
- Unrelated accent colors

The PPT should visually feel like it belongs to the company.

================================================
CRITICAL VISUAL INSTRUCTION
================================================

This is NOT a text-heavy presentation.

The PPT must contain substantial visual storytelling.

For each slide:

- At least 1 major data visualization
- At least 2 supporting visual elements
- 2–5 large numerical callouts
- Minimal paragraphs
- Minimal bullet points
- Strong visual hierarchy

Convert text into visuals whenever possible.

For example:

Instead of writing:

"Customers with multiple products generate more revenue and
have lower churn."

Create a visual ladder:

1 PRODUCT
₹5,500 revenue
22% churn

↓

2 PRODUCTS
₹11,500 revenue
12% churn

↓

3+ PRODUCTS
₹18,000 revenue
5% churn

Instead of writing:

"Urban has the largest broadband opportunity."

Create a visual comparison:

DIGITEL
35% fiber

vs

COMPETITOR
70% fiber

↓

35 percentage-point gap

Instead of writing a long execution plan, create a:

MONTH 1–3 → MONTH 4–8 → MONTH 9–12

visual roadmap.

================================================
SLIDE DESIGN
================================================

SLIDE 1 — WHERE TO PLAY

Use a strong strategic headline.

The slide should visually communicate:

- Core problem
- Strategic thesis
- Portfolio choices
- Target customer
- Geography
- Biggest opportunity

Suggested layout:

TOP:
Insight-driven headline

LEFT:
Portfolio strategy visual

CENTER:
Target customer / geography visual

RIGHT:
Key opportunity numbers

BOTTOM:
Major strategic chart

Use brand colors consistently.

------------------------------------------------

SLIDE 2 — HOW TO WIN

Use a strong action-oriented headline.

The slide should visually communicate:

- Execution roadmap
- AI / technology levers
- KPIs
- Financial/business impact

Suggested layout:

TOP:
Insight-driven headline

LEFT:
12-month roadmap

CENTER:
AI / innovation visual

RIGHT:
KPI cards

BOTTOM:
Waterfall / revenue bridge / impact visualization

------------------------------------------------

SLIDE 3 — OPTIONAL

Only create Slide 3 if the case genuinely requires additional
information.

Possible content:

- Risks and mitigation
- Competitive advantage
- Why we win
- Detailed financial bridge

Do not create Slide 3 merely to add more content.

================================================
VISUAL DESIGN RULES
================================================

Use:

- Clean white/light background
- Strong brand-color accents
- Large numbers
- Clear hierarchy
- Consistent spacing
- Consistent alignment
- Professional icons
- Simple diagrams
- High-quality charts
- Strategic arrows
- Visual frameworks

Avoid:

- Huge paragraphs
- Excessive bullet points
- Random colorful boxes
- Unnecessary gradients
- Decorative graphics
- Generic stock photos
- Too many colors
- Tiny text
- Clutter

Charts must be easy to read.

Numbers must be large enough to understand immediately.

================================================
DATA INTEGRITY
================================================

Do NOT invent numerical data.

Every number must be:

1. Directly provided in the case, OR
2. A transparent calculation using case data.

If a number is calculated, label it clearly.

Do not manufacture market sizes, revenue projections,
customer numbers or financial impact.

================================================
SOURCE REFERENCES
================================================

Where appropriate, include small source references such as:

Source: Exhibit 1
Source: Exhibit 4
Source: Case Exhibit 7

Keep source references subtle and professional.

================================================
FINAL QUALITY CHECK
================================================

Before finalizing the PPT, verify:

[ ] Correct company brand colors used
[ ] No unrelated colors
[ ] Brand identity is visually consistent
[ ] Logo is correct if available
[ ] At least one major visual on every slide
[ ] Supporting visuals on every slide
[ ] Important numbers are prominent
[ ] No unnecessary paragraphs
[ ] No generic decorative graphics
[ ] Charts communicate actual insights
[ ] Strategy is understandable within 10 seconds
[ ] All numbers come from the case or transparent calculations
[ ] Case slide limit is respected
[ ] Presentation looks like an executive case competition deck

If any requirement fails, redesign the slide before finalizing it.

================================================
CASE CONTENT FOR CLAUDE
================================================

Now use the following analysis to create the presentation:

[INSERT GEMINI'S CASE ANALYSIS HERE]

================================================
FINAL OUTPUT
================================================

Return ONLY the complete READY-TO-COPY CLAUDE PROMPT after completing
the analysis.

response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=prompt
)
"""
# print(response.text)

# %%
# ============================================================
# 7. SEND TO GEMINI
# ============================================================

print("\n")
print("=" * 70)
print("ANALYZING CASE STUDY WITH GEMINI...")
print("=" * 70)

response = client.interactions.create(
    model="gemini-3.6-flash",
    input=prompt
)


# ============================================================
# 8. GET GEMINI OUTPUT
# ============================================================

analysis_result = response.output_text


# ============================================================
# 9. DISPLAY RESULT
# ============================================================

print("\n")
print("=" * 70)
print("AI CASE STUDY ANALYSIS")
print("=" * 70)

print(analysis_result)


# ============================================================
# 10. SAVE THE ANALYSIS TO A TEXT FILE
# ============================================================

output_file = "AI_Case_Study_Analysis.txt"

with open(output_file, "w", encoding="utf-8") as f:
    f.write(analysis_result)

print("\n")
print("=" * 70)
print("ANALYSIS SAVED")
print("=" * 70)

print("File:", output_file)
# Out:
# ...
# ANALYZING CASE STUDY WITH GEMINI...
# ...
#
#
# ...
# AI CASE STUDY ANALYSIS
# ...
# ### SECTION 1 — CASE IN SIMPLE WORDS
#
# *   **A. Who is the company?**
#     ITC Limited, operating its flagship premium personal care brand **Tiama** (currently generating ₹750–800 crore in annual consumer spending, growing at >20% CAGR, with an ambition to cross ₹1,000 crore).
# *   **B. What is happening?**
#     Tiama created a new sub-category by launching *Tiama Moisturizing Bars with Japanese Bokkaido Milk* in December 2024. It entered a ₹1,200+ crore moisturizing soap market historically dominated (95% share) by a single incumbent (Dove). Tiama launched first in Modern Trade (MT) and E-commerce, achieving strong sell-out growth.
# *   **C. What is the main problem?**
# ...
